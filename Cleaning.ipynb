# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
filename = list(uploaded.keys())[0]   # get uploaded filename
df = pd.read_excel(filename) # Changed from pd.read_csv to pd.read_excel

print("Loaded:", filename)
#Display dataset structure (head, shape, datatypes)
df.head()
# Out:
#      <input type="file" id="files-70f57100-a025-4033-9c9b-b25b7f46ab8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70f57100-a025-4033-9c9b-b25b7f46ab8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10010 entries, 0 to 10009
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10010 non-null  datetime64[ns]
#  1   Department      10009 non-null  object
#  2   Category        10009 non-null  object
#  3   Region          10007 non-null  object
#  4   Budget Amount   10010 non-null  int64
#  5   Actual Amount   10010 non-null  int64
#  6   Payment Method  10010 non-null  object
#  7   Transaction ID  10007 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 625.8+ KB

# %%
df.describe()
# Out:
#                                 Date  Budget Amount  Actual Amount
# count                          10010   10010.000000   10010.000000
# mean   2022-07-08 14:11:29.070928896   79531.584316   89031.239261
# min              2021-01-01 00:00:00   10005.000000    8002.000000
# 25%              2021-10-08 00:00:00   44379.000000   48570.250000
# 50%              2022-07-12 00:00:00   79515.500000   89188.000000
# 75%              2023-04-09 00:00:00  114575.250000  130586.000000
# max              2023-12-31 00:00:00  149992.000000  169973.000000
# std                              NaN   40490.798172   46947.492216

# %% [markdown]
# DATA WRANGLING & CLEANING

# %%
#Check missing values
df.isnull().sum()
# Out:
# Date              0
# Department        1
# Category          1
# Region            3
# Budget Amount     0
# Actual Amount     0
# Payment Method    0
# Transaction ID    3
# dtype: int64

# %%
#Remove Duplicates
df.drop_duplicates()
# Out:
#            Date Department   Category   Region  Budget Amount  Actual Amount  \
# 0    2023-05-11      Sales     Travel    North         126096          43048
# 1    2023-11-11  Marketing   Salaries     East          19702          87896
# 2    2021-05-02         IT   Training  Central         108523         103632
# 3    2022-04-12  Marketing   Salaries    North         114711         105574
# 4    2021-11-27      Sales  Utilities  Central         121895          64314
# ...         ...        ...        ...      ...            ...            ...
# 9995 2022-09-05      Sales     Travel    South          60191          77111
# 9996 2022-11-28  Marketing  Marketing     East         123316          43319
# 9997 2022-08-26         IT   Salaries     West         106915         103450
# 9998 2021-09-05    Finance     Travel     East          99875          65338
# 9999 2021-12-25    Finance  Utilities     East         115870          38190
#
#      Payment Method Transaction ID
# ...

# %%
# Handling Missing Values
df.dropna(inplace=True)
print('DataFrame after dropping rows with missing values:')
df.isnull().sum()
# Out:
# DataFrame after dropping rows with missing values:
# Date              0
# Department        0
# Category          0
# Region            0
# Budget Amount     0
# Actual Amount     0
# Payment Method    0
# Transaction ID    0
# dtype: int64

# %%
# Save the cleaned DataFrame to an Excel file
output_filename = 'cleaned_budget_vs_actual_data.xlsx'
df.to_excel(output_filename, index=False)

# Provide the file for download
from google.colab import files
files.download(output_filename)

print(f"Cleaned data saved to {output_filename} and is ready for download.")
# Out:
# Cleaned data saved to cleaned_budget_vs_actual_data.xlsx and is ready for download.
